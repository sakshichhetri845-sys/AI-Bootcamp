# %%
print('Hello bootcamp')
print('*-*')
# Out:
# Hello bootcamp
# *-*

# %%
l=[3,4,5,'sakshi']
l.append('hello')
l
# Out:
# [3, 4, 5, 'sakshi', 'hello']

# %%
l.remove(3)
l
# Out:
# [4, 5, 'sakshi', 'hello']

# %%
del l[0]
l
# Out:
# [5, 'sakshi', 'hello']

# %%
m=[1,3,64,21,10]
m.sort()
m
# Out:
# [1, 3, 10, 21, 64]

# %%
m.sort(reverse=True)
m
# Out:
# [64, 21, 10, 3, 1]

# %%
lis=[s**2 for s in range(1,10)]
lis
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
pair={1:2,'black':'white','first':1,'one':1}
pair.keys()
# Out:
# dict_keys([1, 'black', 'first', 'one'])

# %%
pair.get('first')
# Out:
# 1

# %%
pair.popitem()
# Out:
# ('one', 1)

# %%
pair.items()
# Out:
# dict_items([(1, 2), ('black', 'white'), ('first', 1)])

# %%
pair.values()
# Out:
# dict_values([2, 'white', 1])

# %%
pair[3]=(2,3,4,5)
pair
# Out:
# {1: 2, 'black': 'white', 'first': 1, 3: (2, 3, 4, 5)}

# %%
ind=list(pair.keys())[0]
ind
# Out:
# 1

# %%
tup=(2,45,32,11,34,55,11,11)
tup[5]
# Out:
# 55

# %%
tup[2:5]
# Out:
# (32, 11, 34)

# %%
tup.index(32)
# Out:
# 2

# %%
tup.count(11)
# Out:
# 3

# %%
len(tup)
# Out:
# 8
